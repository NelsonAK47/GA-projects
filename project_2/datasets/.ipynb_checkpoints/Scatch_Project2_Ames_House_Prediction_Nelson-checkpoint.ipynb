# %% [markdown]
# # <font color = 'Maroon'> Project 2 - Ames Housing Data Sale Price Prediction
# ---

# %% [markdown]
# ## <font color = 'Maroon'> Background

# %% [markdown]
# One of the big milestones in life is to buy a house. It has become one of the American dreams. Some people purchase houses for investments, others purchase for residence purpose.
# As a property agent in Ames Iowa, I am building a house price prediction model using historical property transactions from Ames Iowa and subsequently advise on clients on their houses value and whether they should sell their houses based on their comfortable sale prices. The dataset can be found via [this link](https://www.kaggle.com/competitions/dsi-us-11-project-2-regression-challenge/)

# %% [markdown]
# The data consists of two csv files as elaborated below:
# - train.csv -> Contains 2051 house transactions with 81 house features consisting of 24 nominal (categorical features with no particular order), 23 ordinal (categorical features with ordering), 15 discrete (countable numerical features) and 20 continuous variables (uncountably infinite numerical features)
# - test.csv -> Contains 878 clients' houses with 81 house features ready to be predicted for their houses value

# %% [markdown]
# Refer to full data dictionary [here](http://jse.amstat.org/v19n3/decock/DataDocumentation.txt)

# %% [markdown]
# ## <font color = 'Maroon'> Content
# - [Background](#Background)
# - [Problem Statement](#Problem-Statement)
# - [Training Set Data Import and Preprocessing](#Training-Set-Data-Import-and-Preprocessing)
# - [Machine Learning Models Optimisation](#Machine-Learning-Models-Optimisation)
# - [Test Set Data Import and Preprocessing](#Test-Set-Data-Import-and-Preprocessing)
# - [Test Set House Sale Price Prediction](#Test-Set-House-Sale-Price-Prediction)
# - [Summary and Conclusion](#Summary-and-Conclusion)

# %% [markdown]
# ## <font color = 'Maroon'> Problem Statement

# %% [markdown]
# House price insights are important information that people refer either when they are looking to sell their houses or just to get their property value and hence, their net worth. It plays a very prominent role in determining the owners' next move.
#
# As a property agent in Ames Iowa, this project aims to provide better visibility and advice for clients regarding to their property value by building a machine learning model for house price prediction. Apart from that, additional information regarding house features that matter to determine the house price can also be provided.

# %% [markdown]
# ## <font color = 'Maroon'> Training Set Data Import and Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import sqrt
from sklearn import datasets
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.experimental import enable_iterative_imputer 
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('../datasets/train.csv')

# %%
train_df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# ...

# %%
train_df['MS SubClass'] = train_df['MS SubClass'].astype(str)

# %%
pd.set_option('display.max_rows', 85)
train_df.dtypes
# Out:
# Id                   int64
# PID                  int64
# MS SubClass         object
# MS Zoning           object
# Lot Frontage       float64
# Lot Area             int64
# Street              object
# Alley               object
# Lot Shape           object
# Land Contour        object
# Utilities           object
# Lot Config          object
# Land Slope          object
# Neighborhood        object
# Condition 1         object
# Condition 2         object
# Bldg Type           object
# House Style         object
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style          object
# Roof Matl           object
# Exterior 1st        object
# Exterior 2nd        object
# Mas Vnr Type        object
# Mas Vnr Area       float64
# Exter Qual          object
# Exter Cond          object
# Foundation          object
# Bsmt Qual           object
# Bsmt Cond           object
# Bsmt Exposure       object
# ...

# %%
#As per special notes in Data Documentation, need to check the plot of sale price vs GR LIV area
sns.pairplot(train_df, vars =['Gr Liv Area', 'SalePrice'])

# %%
#Drop outliers in which we drop Gr Liv Area > 4000
train_df = train_df.drop(train_df[(train_df['Gr Liv Area'] >4000)].index)
train_df.reset_index(inplace=True)

# %%
train_df.head()
# Out:
#    index   Id        PID MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      0  109  533352170          60        RL           NaN     13517   Pave
# 1      1  544  531379050          60        RL          43.0     11492   Pave
# 2      2  153  535304180          20        RL          68.0      7922   Pave
# 3      3  318  916386060          60        RL          73.0      9802   Pave
# 4      4  255  906425045          50        RL          82.0     14235   Pave
#
#   Alley Lot Shape  ... Screen Porch Pool Area Pool QC Fence Misc Feature  \
# 0   NaN       IR1  ...            0         0     NaN   NaN          NaN
# 1   NaN       IR1  ...            0         0     NaN   NaN          NaN
# 2   NaN       Reg  ...            0         0     NaN   NaN          NaN
# 3   NaN       Reg  ...            0         0     NaN   NaN          NaN
# 4   NaN       IR1  ...            0         0     NaN   NaN          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  SalePrice
# ...

# %%
#Plot with outliers removed
sns.pairplot(train_df, vars =['Gr Liv Area', 'SalePrice'])

# %%
print(train_df.shape)
# Out:
# (2049, 82)

# %% [markdown]
# 2 outliers were removed based on Gr Liv Area > 4000

# %%
#Check for null values
train_null_df =train_df.isnull().sum()/2049*100

# %%
train_null_df.sort_values(ascending = False)
# Out:
# Pool QC            99.609566
# Misc Feature       96.876525
# Alley              93.167399
# Fence              80.478282
# Fireplace Qu       48.804295
# Lot Frontage       16.105417
# Garage Yr Blt       5.563690
# Garage Finish       5.563690
# Garage Qual         5.563690
# Garage Cond         5.563690
# Garage Type         5.514885
# Bsmt Exposure       2.830649
# BsmtFin Type 2      2.733041
# BsmtFin Type 1      2.684236
# Bsmt Cond           2.684236
# Bsmt Qual           2.684236
# Mas Vnr Type        1.073694
# Mas Vnr Area        1.073694
# Bsmt Half Bath      0.097609
# Bsmt Full Bath      0.097609
# BsmtFin SF 2        0.048804
# Bsmt Unf SF         0.048804
# BsmtFin SF 1        0.048804
# Total Bsmt SF       0.048804
# Garage Cars         0.048804
# Garage Area         0.048804
# Lot Config          0.000000
# Roof Matl           0.000000
# Id                  0.000000
# PID                 0.000000
# MS SubClass         0.000000
# MS Zoning           0.000000
# ...

# %%
train_consist_null = train_null_df > 0
train_consist_null_df = train_null_df[train_consist_null]
train_consist_null_ordered_df = train_consist_null_df.sort_values()

# %%
#Plot the horizontal bar chart that contain null values
fig = plt.figure(figsize=(30,20))
train_consist_null_ordered_df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# checking if need to remove columns with null values > 45% proportions
train_consist_null_ordered_df.sort_values(ascending = False)
# Out:
# Pool QC           99.609566
# Misc Feature      96.876525
# Alley             93.167399
# Fence             80.478282
# Fireplace Qu      48.804295
# Lot Frontage      16.105417
# Garage Yr Blt      5.563690
# Garage Cond        5.563690
# Garage Qual        5.563690
# Garage Finish      5.563690
# Garage Type        5.514885
# Bsmt Exposure      2.830649
# BsmtFin Type 2     2.733041
# BsmtFin Type 1     2.684236
# Bsmt Cond          2.684236
# Bsmt Qual          2.684236
# Mas Vnr Type       1.073694
# Mas Vnr Area       1.073694
# Bsmt Half Bath     0.097609
# Bsmt Full Bath     0.097609
# Garage Cars        0.048804
# BsmtFin SF 1       0.048804
# BsmtFin SF 2       0.048804
# Bsmt Unf SF        0.048804
# Garage Area        0.048804
# Total Bsmt SF      0.048804
# dtype: float64

# %%
import pprint
# Creating a dictionary for the columns that contain unique object variables

alpha_df = train_df.select_dtypes(include='object')

unique_dict = {}
for column in alpha_df:
  values = alpha_df[column].astype(str).unique().tolist()
  unique_dict[column] = sorted(values)


pprint.pprint (unique_dict)
# Out:
# {'Alley': ['Grvl', 'Pave', 'nan'],
#  'Bldg Type': ['1Fam', '2fmCon', 'Duplex', 'Twnhs', 'TwnhsE'],
#  'Bsmt Cond': ['Ex', 'Fa', 'Gd', 'Po', 'TA', 'nan'],
#  'Bsmt Exposure': ['Av', 'Gd', 'Mn', 'No', 'nan'],
#  'Bsmt Qual': ['Ex', 'Fa', 'Gd', 'Po', 'TA', 'nan'],
#  'BsmtFin Type 1': ['ALQ', 'BLQ', 'GLQ', 'LwQ', 'Rec', 'Unf', 'nan'],
#  'BsmtFin Type 2': ['ALQ', 'BLQ', 'GLQ', 'LwQ', 'Rec', 'Unf', 'nan'],
#  'Central Air': ['N', 'Y'],
#  'Condition 1': ['Artery',
#                  'Feedr',
#                  'Norm',
#                  'PosA',
#                  'PosN',
#                  'RRAe',
#                  'RRAn',
#                  'RRNe',
#                  'RRNn'],
#  'Condition 2': ['Artery',
#                  'Feedr',
#                  'Norm',
#                  'PosA',
#                  'PosN',
#                  'RRAe',
#                  'RRAn',
#                  'RRNn'],
#  'Electrical': ['FuseA', 'FuseF', 'FuseP', 'Mix', 'SBrkr'],
# ...

# %% [markdown]
# As seen above, those categorical variables (Pool QC, Misc Feature, Alley, Fence,etc) null values mean "No pools , no features or no fences", and it's not missing values so it should neither be dropped nor filled in with mean, median, mode or any imputer. It will just be filled in as None so python does not recognize them as null values. This will then be encoded later. However, those features may or may not be dropped depending on EDA and feature selection stage

# %%
#Fill in categorical features null values with 'None'
categorical_none = train_df[['Pool QC', 'Misc Feature', 'Alley', 'Fence', 'Fireplace Qu','Garage Cond', 'Garage Qual', 'Garage Finish', 'Garage Type','Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2', 'Bsmt Cond', 'Bsmt Qual', 'Mas Vnr Type']]

for features in categorical_none:
    train_df[features] = train_df[features].fillna("None")

# %%
train_df['Lot Frontage'].describe()
# Out:
# count    1719.000000
# mean       68.878999
# std        22.472112
# min        21.000000
# 25%        58.000000
# 50%        68.000000
# 75%        80.000000
# max       313.000000
# Name: Lot Frontage, dtype: float64

# %%
#Trying to use iterative imputer to Lot Frontage null values
lot_frontage_missing_df = train_df[['Lot Area','Lot Frontage']]
impute_lot_frontage = IterativeImputer(estimator = LinearRegression(),random_state = 42,skip_complete=True)

lot_frontage_missing_imputed = impute_lot_frontage.fit_transform(lot_frontage_missing_df)
lot_frontage_missing_imputed_df = pd.DataFrame(lot_frontage_missing_imputed, columns = lot_frontage_missing_df.columns)

train_df["Lot Frontage"] = lot_frontage_missing_imputed_df["Lot Frontage"]
train_df[["Id","Lot Frontage", 'Lot Area']].to_csv('final check for lot frontage lot areaa.csv')

# %%
train_df[["Id","Lot Frontage", 'Lot Area']]
# Out:
#         Id  Lot Frontage  Lot Area
# 0      109     78.939510     13517
# 1      544     43.000000     11492
# 2      153     68.000000      7922
# 3      318     73.000000      9802
# 4      255     82.000000     14235
# ...    ...           ...       ...
# 2044  1587     79.000000     11449
# 2045   785     75.941712     12342
# 2046   916     57.000000      7558
# 2047   639     80.000000     10400
# 2048    10     60.000000      7500
#
# [2049 rows x 3 columns]

# %%
train_df['Lot Frontage'].describe()
# Out:
# count    2049.000000
# mean       70.029488
# std        24.159625
# min        21.000000
# 25%        60.000000
# 50%        69.000000
# 75%        80.000000
# max       450.112826
# Name: Lot Frontage, dtype: float64

# %% [markdown]
# Null values in lot frontage has been imputed. Based on the statistics, the values don't differ so much compared to pre-imputation and distribution should be similar.

# %%
#Add Features  -> Yr Sold - Year Built = Building Age
train_df.insert(79,'Building Age',train_df['Yr Sold'] - train_df['Year Built'])

# %% [markdown]
# ### <font color = 'Maroon'> Exploratory Data Analysis

# %% [markdown]
# Since variables with relatively high null value counts have been imputed/filled, i decided to plot the charts of Sale Price vs each features. Those with relatively low null value counts will be imputed based on iterative imputer and variables in relation to them are required to be encoded. Hence, once i encode those variables, it will be hard to visualise the charts

# %%
#List down categorical features
def categorical_features(df):
    lst=[]
    for col in df.columns:
        if (df[col].dtype == 'object'):
            lst.append(col)
    return lst

cat_features = categorical_features(train_df)
np.array(cat_features)
# Out:
# array(['MS SubClass', 'MS Zoning', 'Street', 'Alley', 'Lot Shape',
#        'Land Contour', 'Utilities', 'Lot Config', 'Land Slope',
#        'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual', 'Exter Cond',
#        'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC',
#        'Central Air', 'Electrical', 'Kitchen Qual', 'Functional',
#        'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Pool QC', 'Fence', 'Misc Feature',
#        'Sale Type'], dtype='<U14')

# %%
#List down Numerical Features
non_cat_features = [col for col in train_df.columns if col not in cat_features]
np.array(non_cat_features)
# Out:
# array(['index', 'Id', 'PID', 'Lot Frontage', 'Lot Area', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Mas Vnr Area',
#        'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area',
#        'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath', 'Half Bath',
#        'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd', 'Fireplaces',
#        'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Wood Deck SF',
#        'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch',
#        'Pool Area', 'Misc Val', 'Mo Sold', 'Building Age', 'Yr Sold',
#        'SalePrice'], dtype='<U15')

# %%
lasso_df = train_df[['PID', 'MS SubClass', 'MS Zoning', 'Lot Area', 'Street', 'Alley',
       'Lot Shape', 'Land Contour', 'Neighborhood', 'Condition 1',
       'Condition 2', 'Bldg Type', 'Overall Qual', 'Overall Cond',
       'Year Built', 'Year Remod/Add', 'Roof Style', 'Exterior 1st',
       'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
       'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
       'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Total Bsmt SF',
       'Heating', 'Heating QC', 'Central Air', 'Electrical', 'Low Qual Fin SF',
       'Gr Liv Area', 'Bsmt Full Bath', 'Bedroom AbvGr', 'Kitchen AbvGr',
       'Kitchen Qual', 'TotRms AbvGrd', 'Functional', 'Fireplace Qu',
       'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
       'Garage Area', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
       'Screen Porch', 'Misc Val', 'Building Age', 'Sale Type', 'SalePrice']]

# %%
categorical_features(lasso_df)
# Out:
# ['MS SubClass',
#  'MS Zoning',
#  'Street',
#  'Alley',
#  'Lot Shape',
#  'Land Contour',
#  'Neighborhood',
#  'Condition 1',
#  'Condition 2',
#  'Bldg Type',
#  'Roof Style',
#  'Exterior 1st',
#  'Exterior 2nd',
#  'Mas Vnr Type',
#  'Exter Qual',
#  'Exter Cond',
#  'Foundation',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'Heating',
#  'Heating QC',
#  'Central Air',
#  'Electrical',
#  'Kitchen Qual',
#  'Functional',
#  'Fireplace Qu',
#  'Garage Type',
#  'Garage Finish',
#  'Paved Drive',
#  'Sale Type']

# %%
#Get all categorical plots

#To plot count plots for all categorical features (To sieve out categories with very uneven high counts that can cause bias)

def countplotter(df, y, row , ax):
    sns.countplot(
        data=df,
        y=y,
        order = df.groupby(y)[['SalePrice']].mean().sort_values(by='SalePrice').index,
        ax=ax,
        palette = 'rainbow',
        edgecolor=sns.color_palette("dark:black", 3))
    threshold_line = ax.axvline(0.7 * row, ls='--', c='red', label='Threshold Line')
    
#To plot boxplot for all categorical features (To check on the distribution in general)
def boxplotter(df, x, y, ax):
        sns.boxplot(data=df,
                    x=x,
                    y=y,
                    ax=ax, palette = 'rainbow',
                    order = df.groupby(y)[[x]].mean().sort_values(by=x).index,
                    orient ='h')
        ax.set_xlabel(x)
        ax.yaxis.label.set_size(12)
        ax.xaxis.label.set_size(12)
        
#Fit both plots at one-go
def categorical_plotter(df, categorical_ft):
    for col in categorical_ft:
        number_of_cat = len(df[col].unique())
        graph_height = int(number_of_cat/2)
        fig, ax = plt.subplots(nrows=1,
                               ncols=2,
                               figsize=(14, graph_height),
                               sharey=True,
                              gridspec_kw={'width_ratios': [1,3]} 
                              );
        ax=ax.ravel();
        row = len(df)
        countplotter(df, col, row, ax[0]);
        boxplotter(df,'SalePrice',col, ax[1]);
        plt.rcParams.update({'figure.max_open_warning': 0})

# %%
categorical_plotter(train_df, cat_features)

# %% [markdown]
# As seen above, those variables with threshold > 70% of data will be potentially dropped as this might introduce bias to the model e.g. Sale Type in which more than 70% of the data is WD and Pool QC in which majority of the features are 'None'. We will revisit the features to be dropped again at a later stage before modelling later on. Based on some observations, house style with higher counts of storeys, basement quality, exposure, heating quality have slight correlation to Sale price

# %%
#Get all numerical plots
def scatterplotter(df, columns, y_target):
    ncols = 4
    nrows = int((len(columns)/ncols))
    
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, nrows*4))
    ax = ax.ravel()
    for i, col in enumerate(columns):
        sns.regplot(data=df,
                    x=col,
                    y=y_target,
                    ax=ax[i],
                    line_kws={'color':'brown','lw':5})
        ax[i].set_xlabel('')
        ax[i].yaxis.label.set_size(12)
        ax[i].set_title(col, fontsize=10);
                
    plt.tight_layout()
    plt.suptitle('Scatterplot of Numerical Features vs Sale Price', fontsize=30, y = 1.01)

# %%
scatterplotter(train_df, non_cat_features, 'SalePrice')

# %%
#Plot Gr Live Area
fig_dimensions= (10,5)
fig = plt.figure(figsize = fig_dimensions)
ax1 = fig.add_subplot(111)

sns.regplot(data = train_df,
               x='Gr Liv Area',
               y='SalePrice',
               ax = ax1,
               line_kws={'color':'brown', 'lw':5})
ax1.set_xlabel('Gr Liv Area')

plt.title('SalePrice vs Gr Liv Area')
# Out:
# Text(0.5, 1.0, 'SalePrice vs Gr Liv Area')

# %%
#Plot Gr Live Area
fig_dimensions= (10,5)
fig = plt.figure(figsize = fig_dimensions)
ax1 = fig.add_subplot(111)

sns.regplot(data = train_df,
               x='Garage Area',
               y='SalePrice',
               ax = ax1,
               line_kws={'color':'brown', 'lw':5})
ax1.set_xlabel('Garage Area')

plt.title('SalePrice vs Garage Area ')
# Out:
# Text(0.5, 1.0, 'SalePrice vs Garage Area ')

# %%
#Plot Gr Live Area
fig_dimensions= (10,5)
fig = plt.figure(figsize = fig_dimensions)
ax1 = fig.add_subplot(111)

sns.boxplot(data = train_df,
               x='Overall Qual',
               y='SalePrice',
               ax = ax1, palette = 'rainbow')
# Out:
# <AxesSubplot:xlabel='Overall Qual', ylabel='SalePrice'>

# %%
#Plot Gr Live Area
fig_dimensions= (10,5)
fig = plt.figure(figsize = fig_dimensions)
ax1 = fig.add_subplot(111)

sns.boxplot(data = train_df,
               x='Garage Cars',
               y='SalePrice',
               ax = ax1, palette = 'rainbow')
ax1.set_xlabel('Garage Cars')
ax1.set_title('SalePrice vs Garage Cars')
# Out:
# Text(0.5, 1.0, 'SalePrice vs Garage Cars')

# %%
#Plot Gr Live Area
fig_dimensions= (10,5)
fig = plt.figure(figsize = fig_dimensions)
ax1 = fig.add_subplot(111)

sns.regplot(data = train_df,
               x='Total Bsmt SF',
               y='SalePrice',
               ax = ax1,
               line_kws={'color':'brown', 'lw':5})
ax1.set_xlabel('Total Bsmt SF')

plt.title('SalePrice vs Total Bsmt SF')
# Out:
# Text(0.5, 1.0, 'SalePrice vs Total Bsmt SF')

# %%
#Plot Gr Live Area
fig_dimensions= (10,5)
fig = plt.figure(figsize = fig_dimensions)
ax1 = fig.add_subplot(111)

sns.regplot(data = train_df,
               x='Misc Val',
               y='SalePrice',
               ax = ax1,
               line_kws={'color':'brown', 'lw':5})
ax1.set_xlabel('Misc Val')

plt.title('SalePrice vs Misc Val')
# Out:
# Text(0.5, 1.0, 'SalePrice vs Misc Val')

# %%
#Plot Gr Live Area
fig_dimensions= (10,5)
fig = plt.figure(figsize = fig_dimensions)
ax1 = fig.add_subplot(111)

sns.boxplot(data = train_df,
               x='Yr Sold',
               y='SalePrice',
               ax = ax1, palette = 'rainbow')
ax1.set_xlabel('Yr Sold')
ax1.set_title('SalePrice vs Yr Sold')
# Out:
# Text(0.5, 1.0, 'SalePrice vs Yr Sold')

# %%
#Plot Gr Live Area
fig_dimensions= (10,5)
fig = plt.figure(figsize = fig_dimensions)
ax1 = fig.add_subplot(111)

sns.regplot(data = train_df,
               x='BsmtFin SF 2',
               y='SalePrice',
               ax = ax1,
               line_kws={'color':'brown', 'lw':5})
ax1.set_xlabel('BsmtFin SF 2')

plt.title('SalePrice vs BsmtFin SF 2')
# Out:
# Text(0.5, 1.0, 'SalePrice vs BsmtFin SF 2')

# %%
#Plot Gr Live Area
fig_dimensions= (10,5)
fig = plt.figure(figsize = fig_dimensions)
ax1 = fig.add_subplot(111)

sns.regplot(data = train_df,
               x='Pool Area',
               y='SalePrice',
               ax = ax1,
               line_kws={'color':'brown', 'lw':5})
ax1.set_xlabel('Pool Area')

plt.title('SalePrice vs Pool Area')
# Out:
# Text(0.5, 1.0, 'SalePrice vs Pool Area')

# %%
#Plot Gr Live Area
fig_dimensions= (10,5)
fig = plt.figure(figsize = fig_dimensions)
ax1 = fig.add_subplot(111)

sns.regplot(data = train_df,
               x='Total Bsmt SF',
               y='SalePrice',
               ax = ax1,
               line_kws={'color':'brown', 'lw':5})
ax1.set_xlabel('Total Bsmt SF')

plt.title('SalePrice vs Total Bsmt SF')
# Out:
# Text(0.5, 1.0, 'SalePrice vs Total Bsmt SF')

# %% [markdown]
# There are several features that are highly correlated to saleprice e.g. Overall Qual, Gr Liv Area, Building Age, Total Bsmt SF, 1st Flr SF,etc. Suggest to keep those features and drop features that have low correlation. This will be done at a later stage before modelling

# %% [markdown]
# After taking a look at possible features to be removed, proceed to impute variables with low null values to check for correlations and colinearity.

# %%
#Impute Bsmt Full Bath and Bsmt Half Bath
Bsmt_Bath_missing_df = train_df[['BsmtFin Type 1','BsmtFin Type 2','BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Full Bath', 'Bsmt Half Bath']]
Bsmt_Bath_missing_corr = Bsmt_Bath_missing_df.corr()
corr_color = Bsmt_Bath_missing_corr.style.background_gradient(cmap='coolwarm').set_precision(2).set_caption("Heat maps for Cleaned train dataset")
display(Bsmt_Bath_missing_corr)
# Out:
#                 BsmtFin SF 1  BsmtFin SF 2  Bsmt Full Bath  Bsmt Half Bath
# BsmtFin SF 1        1.000000     -0.049885        0.657027        0.068234
# BsmtFin SF 2       -0.049885      1.000000        0.157994        0.094727
# Bsmt Full Bath      0.657027      0.157994        1.000000       -0.149399
# Bsmt Half Bath      0.068234      0.094727       -0.149399        1.000000

# %%
#Encode BsmtFin Type 1 and BsmtFin Type 2 to check for further correlation
train_df['BsmtFin Type 1'] = train_df['BsmtFin Type 1'].map({'None' :0,'Unf' :1, 'LwQ' :2, 'Rec' :3, 'BLQ' :4,'ALQ' :5 ,'GLQ' :6})
train_df['BsmtFin Type 2'] = train_df['BsmtFin Type 2'].map({'None' :0,'Unf' :1, 'LwQ' :2, 'Rec' :3, 'BLQ' :4,'ALQ' :5 ,'GLQ' :6})
Bsmt_Bath_missingg_df = train_df[['BsmtFin Type 1','BsmtFin Type 2','BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Full Bath', 'Bsmt Half Bath']]
Bsmt_Bath_missingg_corr = Bsmt_Bath_missingg_df.corr()
corr_color = Bsmt_Bath_missingg_corr.style.background_gradient(cmap='coolwarm').set_precision(2).set_caption("Heat maps for Cleaned train dataset")
display(Bsmt_Bath_missingg_corr)
# Out:
#                 BsmtFin Type 1  BsmtFin Type 2  BsmtFin SF 1  BsmtFin SF 2  \
# BsmtFin Type 1        1.000000        0.110636      0.722855      0.030972
# BsmtFin Type 2        0.110636        1.000000      0.000705      0.777928
# BsmtFin SF 1          0.722855        0.000705      1.000000     -0.049885
# BsmtFin SF 2          0.030972        0.777928     -0.049885      1.000000
# Bsmt Full Bath        0.592259        0.173701      0.657027      0.157994
# Bsmt Half Bath        0.062388        0.117703      0.068234      0.094727
#
#                 Bsmt Full Bath  Bsmt Half Bath
# BsmtFin Type 1        0.592259        0.062388
# BsmtFin Type 2        0.173701        0.117703
# BsmtFin SF 1          0.657027        0.068234
# BsmtFin SF 2          0.157994        0.094727
# Bsmt Full Bath        1.000000       -0.149399
# Bsmt Half Bath       -0.149399        1.000000

# %%
#Impute Bsmt Full Bath and Bsmt Half Bath
Bsmt_bath_missing = train_df[['BsmtFin Type 1','BsmtFin Type 2','BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Full Bath', 'Bsmt Half Bath']]
impute_bsmt_bath = IterativeImputer()

it_imp_bsmt_bath_missing = impute_bsmt_bath.fit_transform(Bsmt_bath_missing)
it_imp_bsmt_bath_missing = pd.DataFrame(it_imp_bsmt_bath_missing , columns = Bsmt_bath_missing.columns)
it_imp_bsmt_bath_missing[['BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Full Bath', 'Bsmt Half Bath']] = it_imp_bsmt_bath_missing[['BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Full Bath', 'Bsmt Half Bath']].round()

train_df[['BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Full Bath', 'Bsmt Half Bath']] = it_imp_bsmt_bath_missing[['BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Full Bath', 'Bsmt Half Bath']]
train_df.isnull().sum()
# Out:
# index                0
# Id                   0
# PID                  0
# MS SubClass          0
# MS Zoning            0
# Lot Frontage         0
# Lot Area             0
# Street               0
# Alley                0
# Lot Shape            0
# Land Contour         0
# Utilities            0
# Lot Config           0
# Land Slope           0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Roof Matl            0
# Exterior 1st         0
# Exterior 2nd         0
# Mas Vnr Type         0
# Mas Vnr Area        22
# Exter Qual           0
# Exter Cond           0
# Foundation           0
# Bsmt Qual            0
# Bsmt Cond            0
# Bsmt Exposure        0
# BsmtFin Type 1       0
# BsmtFin SF 1         0
# BsmtFin Type 2       0
# BsmtFin SF 2         0
# Bsmt Unf SF          1
# ...

# %%
#Impute Bsmt Unf SF and Total Bsmt SF
Bsmt_missing_df = train_df[['BsmtFin Type 1','BsmtFin Type 2','BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Unf SF', 'Total Bsmt SF']]
impute_bsmt = IterativeImputer()

it_imp_bsmt_missing_imputed = impute_bsmt.fit_transform(Bsmt_missing_df)
it_imp_bsmt_missing_imputed_df = pd.DataFrame(it_imp_bsmt_missing_imputed , columns = Bsmt_missing_df.columns)

it_imp_bsmt_missing_imputed_df[['BsmtFin Type 1','BsmtFin Type 2','BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Unf SF', 'Total Bsmt SF']] =it_imp_bsmt_missing_imputed_df[['BsmtFin Type 1','BsmtFin Type 2','BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Unf SF', 'Total Bsmt SF']].round()

train_df[['BsmtFin Type 1','BsmtFin Type 2','BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Unf SF', 'Total Bsmt SF']] = it_imp_bsmt_missing_imputed_df[['BsmtFin Type 1','BsmtFin Type 2','BsmtFin SF 1', 'BsmtFin SF 2','Bsmt Unf SF', 'Total Bsmt SF']]
train_df.isnull().sum()
# Out:
# index                0
# Id                   0
# PID                  0
# MS SubClass          0
# MS Zoning            0
# Lot Frontage         0
# Lot Area             0
# Street               0
# Alley                0
# Lot Shape            0
# Land Contour         0
# Utilities            0
# Lot Config           0
# Land Slope           0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Roof Matl            0
# Exterior 1st         0
# Exterior 2nd         0
# Mas Vnr Type         0
# Mas Vnr Area        22
# Exter Qual           0
# Exter Cond           0
# Foundation           0
# Bsmt Qual            0
# Bsmt Cond            0
# Bsmt Exposure        0
# BsmtFin Type 1       0
# BsmtFin SF 1         0
# BsmtFin Type 2       0
# BsmtFin SF 2         0
# Bsmt Unf SF          0
# ...

# %%
#Encode Mas Vnr Type to check for further correlation
train_df['Mas Vnr Type'] = train_df['Mas Vnr Type'].map({'None' :0,'Stone' :1, 'CBlock' :2, 'BrkFace' : 3, 'BrkCmn' :4})

# %%
#Impute Mas Vnr Area
mas_vnr_missing_df = train_df[['Mas Vnr Type','Mas Vnr Area']]
impute_mas_vnr = IterativeImputer()

it_imp_mas_vnr_missing_imputed = impute_mas_vnr.fit_transform(mas_vnr_missing_df)
it_imp_mas_vnr_missing_imputed_df = pd.DataFrame(it_imp_mas_vnr_missing_imputed , columns = mas_vnr_missing_df.columns)

it_imp_mas_vnr_missing_imputed_df[['Mas Vnr Type','Mas Vnr Area']] =it_imp_mas_vnr_missing_imputed_df[['Mas Vnr Type','Mas Vnr Area']].round()

train_df[['Mas Vnr Type','Mas Vnr Area']] = it_imp_mas_vnr_missing_imputed_df[['Mas Vnr Type','Mas Vnr Area']]
train_df.isnull().sum()
# Out:
# index                0
# Id                   0
# PID                  0
# MS SubClass          0
# MS Zoning            0
# Lot Frontage         0
# Lot Area             0
# Street               0
# Alley                0
# Lot Shape            0
# Land Contour         0
# Utilities            0
# Lot Config           0
# Land Slope           0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Roof Matl            0
# Exterior 1st         0
# Exterior 2nd         0
# Mas Vnr Type         0
# Mas Vnr Area         0
# Exter Qual           0
# Exter Cond           0
# Foundation           0
# Bsmt Qual            0
# Bsmt Cond            0
# Bsmt Exposure        0
# BsmtFin Type 1       0
# BsmtFin SF 1         0
# BsmtFin Type 2       0
# BsmtFin SF 2         0
# Bsmt Unf SF          0
# ...

# %%
#Encode Garage Type to check for further correlation
train_df['Garage Type'] = train_df['Garage Type'].map({'None' :0,'Detchd' :1, 'CarPort' :2, 'BuiltIn' : 3, 'Basment' :4, 'Attchd': 5, '2Types': 6})

# %%
#Impute Garage Cars and Garage Area
garage_missing_df = train_df[['Garage Type','Garage Cars', 'Garage Area']]
impute_garage = IterativeImputer()

it_imp_garage_missing_imputed = impute_garage.fit_transform(garage_missing_df)
it_imp_garage_missing_imputed_df = pd.DataFrame(it_imp_garage_missing_imputed , columns = garage_missing_df.columns)

it_imp_garage_missing_imputed_df[['Garage Cars', 'Garage Area']] =it_imp_garage_missing_imputed_df[['Garage Cars', 'Garage Area']].round()

train_df[['Garage Cars', 'Garage Area']] = it_imp_garage_missing_imputed_df[['Garage Cars', 'Garage Area']]
train_df.isnull().sum()
# Out:
# index                0
# Id                   0
# PID                  0
# MS SubClass          0
# MS Zoning            0
# Lot Frontage         0
# Lot Area             0
# Street               0
# Alley                0
# Lot Shape            0
# Land Contour         0
# Utilities            0
# Lot Config           0
# Land Slope           0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Roof Matl            0
# Exterior 1st         0
# Exterior 2nd         0
# Mas Vnr Type         0
# Mas Vnr Area         0
# Exter Qual           0
# Exter Cond           0
# Foundation           0
# Bsmt Qual            0
# Bsmt Cond            0
# Bsmt Exposure        0
# BsmtFin Type 1       0
# BsmtFin SF 1         0
# BsmtFin Type 2       0
# BsmtFin SF 2         0
# Bsmt Unf SF          0
# ...

# %%
#Impute Garage Yr Blt -> Empty values mean no garage
train_df['Garage Yr Blt'] = train_df['Garage Yr Blt'].fillna(0)

# %%
#Checking null values again
train_df.isnull().sum()
# Out:
# index              0
# Id                 0
# PID                0
# MS SubClass        0
# MS Zoning          0
# Lot Frontage       0
# Lot Area           0
# Street             0
# Alley              0
# Lot Shape          0
# Land Contour       0
# Utilities          0
# Lot Config         0
# Land Slope         0
# Neighborhood       0
# Condition 1        0
# Condition 2        0
# Bldg Type          0
# House Style        0
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Roof Style         0
# Roof Matl          0
# Exterior 1st       0
# Exterior 2nd       0
# Mas Vnr Type       0
# Mas Vnr Area       0
# Exter Qual         0
# Exter Cond         0
# Foundation         0
# Bsmt Qual          0
# Bsmt Cond          0
# Bsmt Exposure      0
# BsmtFin Type 1     0
# BsmtFin SF 1       0
# BsmtFin Type 2     0
# BsmtFin SF 2       0
# Bsmt Unf SF        0
# Total Bsmt SF      0
# Heating            0
# Heating QC         0
# ...

# %%
#List down categorical features
def categorical_features(df):
    lst=[]
    for col in df.columns:
        if (df[col].dtype == 'object'):
            lst.append(col)
    return lst

cat_features = categorical_features(train_df)
np.array(cat_features)
# Out:
# array(['MS SubClass', 'MS Zoning', 'Street', 'Alley', 'Lot Shape',
#        'Land Contour', 'Utilities', 'Lot Config', 'Land Slope',
#        'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Exter Qual', 'Exter Cond', 'Foundation',
#        'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'Heating', 'Heating QC',
#        'Central Air', 'Electrical', 'Kitchen Qual', 'Functional',
#        'Fireplace Qu', 'Garage Finish', 'Garage Qual', 'Garage Cond',
#        'Paved Drive', 'Pool QC', 'Fence', 'Misc Feature', 'Sale Type'],
#       dtype='<U13')

# %%
#Map categorical features
train_df['Street'] = train_df['Street'].map({'Grvl':1,'Pave' :2})
train_df['Alley'] = train_df['Alley'].map({'None': 0,'Grvl':1,'Pave' :2})
train_df['Lot Shape'] = train_df['Lot Shape'].map({'IR3': 1,'IR2':2,'IR1' :3, 'Reg' :4})
train_df['Land Contour'] = train_df['Land Contour'].map({'Low': 1,'HLS':2,'Bnk' :3, 'Lvl':4})
train_df['Utilities'] = train_df['Utilities'].map({'ELO': 1,'NoSeWa':2,'NoSewr' :3, 'AllPub':4})
train_df['Lot Config'] = train_df['Lot Config'].map({'FR3': 1,'FR2':2,'CulDSac' :3, 'Corner':4, 'Inside': 5})
train_df['Land Slope'] = train_df['Land Slope'].map({'Sev': 1,'Mod':2,'Gtl' :3})
train_df['Neighborhood'] = train_df['Neighborhood'].map({'Veenker': 1,'Timber':2,'StoneBr' :3,'Somerst' :4,'SawyerW' :5,'Sawyer' :6,'SWISU' :7,'OldTown' :8,'NWAmes' :9,'NridgHt' :10,'NPkVill' :11,'NoRidge' :12,'NAmes' :13,'Mitchel' :14,'MeadowV' :15,'Landmrk' :16,'IDOTRR' :17,'GrnHill' :18,'Greens' :19,'Gilbert' :20,'Edwards' :21,'Crawfor' :22,'CollgCr' :23,'ClearCr' :24,'BrkSide' :25,'BrDale' :26,'Blueste' :27,'Blmngtn' :28})
train_df['Condition 1'] = train_df['Condition 1'].map({'RRAe': 1,'RRNe':2,'PosA' :3,'PosN': 4,'RRAn': 5,'RRNn': 6,'Norm': 7,'Feedr': 8,'Artery': 9})
train_df['Condition 2'] = train_df['Condition 2'].map({'RRAe': 1,'RRNe':2,'PosA' :3,'PosN': 4,'RRAn': 5,'RRNn': 6,'Norm': 7,'Feedr': 8,'Artery': 9})
train_df['Bldg Type'] = train_df['Bldg Type'].map({'Twnhs': 1,'TwnhsE':2,'Duplex' :3,'2fmCon':4, '1Fam': 5})
train_df['House Style'] = train_df['House Style'].map({'SLvl': 1,'SFoyer':2,'2.5Unf' :3,'2.5Fin':4, '2Story': 5,'1.5Unf': 6,'1.5Fin': 7,'1Story': 8})
train_df['Roof Style'] = train_df['Roof Style'].map({'Shed': 1,'Mansard':2,'Hip' :3,'Gambrel':4, 'Gable': 5, 'Flat': 6})
train_df['Roof Matl'] = train_df['Roof Matl'].map({'WdShngl': 1,'WdShake':2,'Tar&Grv' :3,'Roll':4, 'Metal': 5,'Membran': 6,'CompShg': 7,'ClyTile': 8})
train_df['Exterior 1st'] = train_df['Exterior 1st'].map({'WdShing': 1,'Wd Sdng':2,'VinylSd' :3,'Stucco':4, 'Stone': 5, 'Plywood': 6,'MetalSd': 7,'ImStucc': 8,'HdBoard': 9,'CemntBd': 10,'CBlock': 11,'BrkFace': 12,'BrkComm': 13,'AsphShn': 14,'AsbShng': 15})
train_df['Exterior 2nd'] = train_df['Exterior 2nd'].map({'Wd Shng': 1,'Wd Sdng':2,'VinylSd' :3,'Stucco':4, 'Stone': 5, 'Plywood': 6,'MetalSd': 7,'ImStucc': 8,'HdBoard': 9,'CmentBd': 10,'CBlock': 11,'BrkFace': 12,'Brk Cmn': 13,'AsphShn': 14,'AsbShng': 15})
train_df['Exter Qual'] = train_df['Exter Qual'].map({'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
train_df['Exter Cond'] = train_df['Exter Cond'].map({'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
train_df['Foundation'] = train_df['Foundation'].map({'Wood': 1,'Stone':2,'Slab' :3,'PConc':4, 'CBlock': 5, 'BrkTil': 6})
train_df['Bsmt Qual'] = train_df['Bsmt Qual'].map({'None': 0,'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
train_df['Bsmt Cond'] = train_df['Bsmt Cond'].map({'None': 0,'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
train_df['Bsmt Exposure'] = train_df['Bsmt Exposure'].map({'None': 0,'No': 1,'Mn':2,'Av' :3,'Gd':4})
train_df['Heating'] = train_df['Heating'].map({'Wall': 1,'OthW': 2,'Grav':3,'GasW' :4,'GasA':5,'Floor':6})
train_df['Heating QC'] = train_df['Heating QC'].map({'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
train_df['Central Air'] = train_df['Central Air'].map({'N':0,'Y' :1})
train_df['Electrical'] = train_df['Electrical'].map({'Mix': 1,'FuseP':2,'FuseF' :3,'FuseA':4, 'SBrkr': 5})
train_df['Kitchen Qual'] = train_df['Kitchen Qual'].map({'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
train_df['Functional'] = train_df['Functional'].map({'Sal': 1,'Sev':2,'Maj2' :3,'Maj1':4, 'Mod': 5,'Min2': 6,'Min1': 7,'Typ': 8})
train_df['Fireplace Qu'] = train_df['Fireplace Qu'].map({'None': 0,'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
train_df['Garage Finish'] = train_df['Garage Finish'].map({'None': 0,'Unf': 1,'RFn':2,'Fin' :3})
train_df['Garage Qual'] = train_df['Garage Qual'].map({'None': 0,'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
train_df['Garage Cond'] = train_df['Garage Cond'].map({'None': 0,'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
train_df['Paved Drive'] = train_df['Paved Drive'].map({'N': 1,'P': 2,'Y':3})
train_df['Pool QC'] = train_df['Pool QC'].map({'None': 0,'Fa':1,'TA' :2,'Gd':3, 'Ex': 4})
train_df['Fence'] = train_df['Fence'].map({'None': 0,'MnWw': 1,'GdWo':2,'MnPrv' :3,'GdPrv':4})
train_df['Misc Feature'] = train_df['Misc Feature'].map({'None': 0,'TenC': 1,'Shed':2,'Othr' :3,'Gar2':4,'Elev':5})
train_df['Sale Type'] = train_df['Sale Type'].map({'Oth': 1,'ConLD':2,'ConLI' :3,'ConLw':4,'Con':5,'COD':6,'New':7, 'CWD':8,'WD ':9})
train_df['MS Zoning'] = train_df['MS Zoning'].map({'RM': 1,'RL' :2,'RH':3,'I (all)':4,'FV':5,'C (all)':6,'A (agr)':7})
train_df['MS SubClass'] = train_df['MS SubClass'].map({'190': 1,'180':2,'160' :3,'150':4,'120':5,'90':6,'85':7,'80':8, '75': 9,'70': 10, '60': 11, '50': 12, '45': 13, '40': 14, '30': 15, '20': 16})

# %%
train_df_corr = train_df.corr()
corr_color = train_df_corr.style.background_gradient(cmap='coolwarm').set_precision(2).set_caption("Heat maps for Cleaned train dataset")
display(corr_color)
# Out:
# <style  type="text/css" >
# ...

# %%
train_df.corr().SalePrice.sort_values(ascending = False)
# Out:
# SalePrice          1.000000
# Overall Qual       0.803462
# Gr Liv Area        0.719463
# Exter Qual         0.715048
# Kitchen Qual       0.694295
# Total Bsmt SF      0.664547
# Garage Area        0.655513
# Garage Cars        0.648671
# 1st Flr SF         0.648252
# Bsmt Qual          0.613236
# Year Built         0.572405
# Garage Finish      0.558566
# Year Remod/Add     0.550872
# Fireplace Qu       0.539484
# Full Bath          0.538225
# Mas Vnr Area       0.512041
# TotRms AbvGrd      0.509775
# Fireplaces         0.473783
# Heating QC         0.458636
# BsmtFin SF 1       0.446153
# Garage Type        0.427940
# Bsmt Exposure      0.426134
# BsmtFin Type 1     0.350728
# Open Porch SF      0.338545
# Wood Deck SF       0.327629
# Lot Frontage       0.324453
# Mas Vnr Type       0.312913
# Lot Area           0.303744
# Paved Drive        0.290528
# Garage Qual        0.285328
# Bsmt Full Bath     0.284433
# Half Bath          0.283372
# Central Air        0.277425
# ...

# %% [markdown]
# It can be observed that the top 10 features that are highly positively correlation to house prices are:
# - Overall Qual
# - Gr Liv Area
# - Exter Qual
# - Kitchen Qual
# - Total Bsmt SF
# - Garage Area
# - Garage Cars
# - 1st Flr SF
# - Bsmt Qual
# - Year Built
#
# Those that have highly negatively correlation to house prices are:
# - Building Age
# - Foundation

# %%
#Remove Index column
train_df.drop('index', axis=1, inplace=True)

# %%
train_df.isnull().sum()
# Out:
# Id                 0
# PID                0
# MS SubClass        0
# MS Zoning          0
# Lot Frontage       0
# Lot Area           0
# Street             0
# Alley              0
# Lot Shape          0
# Land Contour       0
# Utilities          0
# Lot Config         0
# Land Slope         0
# Neighborhood       0
# Condition 1        0
# Condition 2        0
# Bldg Type          0
# House Style        0
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Roof Style         0
# Roof Matl          0
# Exterior 1st       0
# Exterior 2nd       0
# Mas Vnr Type       0
# Mas Vnr Area       0
# Exter Qual         0
# Exter Cond         0
# Foundation         0
# Bsmt Qual          0
# Bsmt Cond          0
# Bsmt Exposure      0
# BsmtFin Type 1     0
# BsmtFin SF 1       0
# BsmtFin Type 2     0
# BsmtFin SF 2       0
# Bsmt Unf SF        0
# Total Bsmt SF      0
# Heating            0
# Heating QC         0
# Central Air        0
# ...

# %% [markdown]
# ## <font color = 'Maroon'> Machine Learning Models Optimisation

# %% [markdown]
# <h3> <font color = 'Maroon'> Model 1 - All Features Model

# %%
#Try to model by including all features
X = train_df.loc[:, train_df.columns != 'SalePrice']
y = train_df[['SalePrice']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %% [markdown]
# <h4> <font color = 'Maroon'> Model 1 - Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
print(f'R2 on train set Model 1(Linear Regression): {lr.score(X_train, y_train)}')
# Out:
# R2 on train set Model 1(Linear Regression): 0.9030641168341722

# %%
cross_val_score(lr, X_train, y_train, cv=5)
# Out:
# array([0.89445524, 0.87209737, 0.89227125, 0.90271724, 0.85863171])

# %%
print(f'R2 on test set(Linear Regression Model 1): {lr.score(X_test, y_test)}')
# Out:
# R2 on test set(Linear Regression Model 1): 0.9024896872500044

# %%
preds_lr = lr.predict(X_test)
preds_lr_train = lr.predict(X_train)

# %%
print(f'RMSE on train set (Linear Regression Model 1): {sqrt(mean_squared_error(y_train, preds_lr_train))}')
print(f'RMSE on test set (Linear Regression Model 1): {sqrt(mean_squared_error(y_test, preds_lr))}')
RMSE_train_1 =sqrt(mean_squared_error(y_train, preds_lr_train))
RMSE_test_1 =sqrt(mean_squared_error(y_test, preds_lr))
# Out:
# RMSE on train set (Linear Regression Model 1): 24302.914043811386
# RMSE on test set (Linear Regression Model 1): 25570.67621957141

# %%
lr.coef_
# Out:
# array([[-1.52043478e+01,  5.20598306e-06,  1.04143310e+03,
#         -7.09007388e+02, -6.94052279e+00,  9.77764799e-01,
#          1.20105479e+04, -3.52795017e+03,  1.26320166e+03,
#         -4.55392277e+03, -1.31672095e-09,  3.91927653e+02,
#         -2.41956122e+02, -1.44935205e+02,  7.08313575e+02,
#         -9.11830517e+03,  4.31731338e+02, -5.17151581e+02,
#          8.90816348e+03,  5.32481622e+03, -3.10631730e+03,
#          5.05283420e+01, -2.46990248e+03,  5.74807346e+02,
#          1.58358633e+03, -1.29002763e+03, -4.66242342e+03,
#          4.46713504e+01,  1.23591491e+04, -4.09007686e+03,
#         -1.86257498e+03,  2.95816536e+03, -7.77090133e+03,
#          4.71330545e+03, -5.29399451e+02,  2.06937876e+01,
#          4.85392505e+02,  2.14784014e+00, -1.00984556e+00,
#          2.18317822e+01,  1.74195280e+03,  1.57620952e+03,
#         -5.71367370e+03, -2.90911365e+03,  1.90258291e+01,
#          1.96063106e+01, -6.78705874e+00,  3.18450810e+01,
# ...

# %% [markdown]
# <h4> <font color = 'Maroon'> Model 1 - Lasso Regression

# %%
ss = StandardScaler()

X_train_s = ss.fit_transform(X_train)
X_test_s = ss.transform(X_test)
optimal_lasso_model_1 = LassoCV(n_alphas=500, cv=10, verbose=1)
optimal_lasso_model_1.fit(X_train_s, y_train)

print (optimal_lasso_model_1.alpha_)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
lasso = Lasso(alpha=optimal_lasso_model_1.alpha_)
lasso.fit(X_train_s, y_train)
lasso_pred_model_1_optimised = lasso.predict(X_test_s)
lasso_pred_model_1_optimised_train = lasso.predict(X_train_s)
R_squared = r2_score(lasso_pred_model_1_optimised, y_test)
print('Test R-squared score (Lasso) :', R_squared)
print(f'RMSE on train set(Lasso Regression Model 1): {sqrt(mean_squared_error(y_train, lasso_pred_model_1_optimised_train))}')
print(f'RMSE on test set(Lasso Regression Model 1): {sqrt(mean_squared_error(y_test, lasso_pred_model_1_optimised))}')
RMSE_train_lasso_1 = sqrt(mean_squared_error(y_train, lasso_pred_model_1_optimised_train))
RMSE_test_lasso_1 = sqrt(mean_squared_error(y_test, lasso_pred_model_1_optimised))
# Out:
# Test R-squared score (Lasso) : 0.8837943470826279
# RMSE on train set(Lasso Regression Model 1): 24477.55994055918
# RMSE on test set(Lasso Regression Model 1): 25496.935322592744

# %% [markdown]
# <h4> <font color = 'Maroon'> Model 1 - Ridge Regression

# %%
optimal_ridge_model_1 = RidgeCV()
optimal_ridge_model_1.fit(X_train_s, y_train)

print (optimal_ridge_model_1.alpha_)
# Out:
# 10.0

# %%
ridge = Ridge(alpha=optimal_ridge_model_1.alpha_)
ridge.fit(X_train_s, y_train)
ridge_pred_model_1_optimised = ridge.predict(X_test_s)
ridge_pred_model_1_optimised_train = ridge.predict(X_train_s)
R_squared = r2_score(ridge_pred_model_1_optimised, y_test)
print('Test R-squared score (Ridge) :', R_squared)
print(f'RMSE on train set(Ridge Regression Model 1): {sqrt(mean_squared_error(y_train, ridge_pred_model_1_optimised_train))}')
print(f'RMSE on test set(Ridge Regression Model 1): {sqrt(mean_squared_error(y_test, ridge_pred_model_1_optimised))}')
RMSE_train_ridge_1 = sqrt(mean_squared_error(y_train, ridge_pred_model_1_optimised_train))
RMSE_test_ridge_1 = sqrt(mean_squared_error(y_test, ridge_pred_model_1_optimised))
# Out:
# Test R-squared score (Ridge) : 0.885578392179036
# RMSE on train set(Ridge Regression Model 1): 24317.722749168825
# RMSE on test set(Ridge Regression Model 1): 25528.915559951605

# %% [markdown]
# <h3> <font color = 'Maroon'> Model 2 - Drop Features based on Lasso Regression Weak Coefficients

# %% [markdown]
# Since Lasso Regression shrinks the coefficients of the weaker variables to 0, Model 2 aims to drop features based on those weak coefficients. Those variables are usually horizontal lines with little or no correlations to target variable

# %% [markdown]
# <h4> <font color = 'Maroon'> Model 2 - Linear Regression

# %%
coefficient_lasso_df = pd.DataFrame()
coefficient_lasso_df['Features'] = X_train.columns
coefficient_lasso_df['Coefficient_Value'] = pd.Series(lasso.coef_)
plt.rcParams['figure.figsize'] = (15,15)
plt.barh(coefficient_lasso_df["Features"], coefficient_lasso_df['Coefficient_Value'])
# Out:
# <BarContainer object of 81 artists>

# %%
coefficient_lasso_abs_sorted_df = coefficient_lasso_df.sort_values(by ='Coefficient_Value', key =abs,ascending = False)
coefficient_lasso_abs_sorted_df
# Out:
#            Features  Coefficient_Value
# 47      Gr Liv Area       25093.064619
# 18     Overall Qual       13611.038626
# 35     BsmtFin SF 1        8918.001950
# 39    Total Bsmt SF        8379.781018
# 78     Building Age       -7832.361143
# 28       Exter Qual        7545.918700
# 54     Kitchen Qual        7361.604170
# 27     Mas Vnr Area        7275.736515
# 26     Mas Vnr Type       -5718.582736
# 19     Overall Cond        5242.870222
# 33    Bsmt Exposure        5029.341829
# 5          Lot Area        4979.447454
# 55    TotRms AbvGrd        4768.797602
# 52    Bedroom AbvGr       -4396.327735
# 32        Bsmt Cond       -3803.521369
# 56       Functional        3777.290158
# 59      Garage Type       -3668.037602
# 58     Fireplace Qu        3513.603562
# 2       MS SubClass        3202.617050
# 71     Screen Porch        3162.657244
# 24     Exterior 1st        3147.581908
# 53    Kitchen AbvGr       -2651.612404
# 9      Land Contour       -2571.997091
# ...

# %%
plt.barh(coefficient_lasso_abs_sorted_df["Features"], coefficient_lasso_abs_sorted_df['Coefficient_Value'])
# Out:
# <BarContainer object of 81 artists>

# %%
coefficient_lasso_abs_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-8410060bf623> in <module>
# ----> 1 coefficient_lasso_abs_df
#
# NameError: name 'coefficient_lasso_abs_df' is not defined

# %%
coefficient_lasso_ordered_df = coefficient_lasso_df.sort_values(by ='Coefficient_Value', ascending= False)
coefficient_lasso_ordered_df

# %%
#Choose features to drop based on -100 < coefficients < 100
lasso_cond1 = coefficient_lasso_df['Coefficient_Value'] < 100
lasso_cond2 = coefficient_lasso_df['Coefficient_Value'] > -100
coefficient_lasso_cond_df = coefficient_lasso_df[lasso_cond1 & lasso_cond2]
coefficient_lasso_cond_df['Features']
# Out:
# 0                 Id
# 4       Lot Frontage
# 10         Utilities
# 11        Lot Config
# 12        Land Slope
# 17       House Style
# 23         Roof Matl
# 36    BsmtFin Type 2
# 38       Bsmt Unf SF
# 44        1st Flr SF
# 45        2nd Flr SF
# 49    Bsmt Half Bath
# 50         Full Bath
# 51         Half Bath
# 57        Fireplaces
# 64       Garage Qual
# 65       Garage Cond
# 69    Enclosed Porch
# 70        3Ssn Porch
# 72         Pool Area
# 73           Pool QC
# 74             Fence
# 75      Misc Feature
# 77           Mo Sold
# 79           Yr Sold
# Name: Features, dtype: object

# %%
coefficient_lasso_cond_to_drop = coefficient_lasso_cond_df['Features']

# %%
train_dropped_lasso_df = train_df.drop(coefficient_lasso_cond_to_drop, axis = 1)

# %%
train_dropped_lasso_df.columns
# Out:
# Index(['PID', 'MS SubClass', 'MS Zoning', 'Lot Area', 'Street', 'Alley',
#        'Lot Shape', 'Land Contour', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remod/Add', 'Roof Style', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bedroom AbvGr', 'Kitchen AbvGr',
#        'Kitchen Qual', 'TotRms AbvGrd', 'Functional', 'Fireplace Qu',
#        'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Screen Porch', 'Misc Val', 'Building Age', 'Sale Type', 'SalePrice'],
#       dtype='object')

# %%
train_dropped_lasso_df.dtypes
# Out:
# PID                  int64
# MS SubClass          int64
# MS Zoning            int64
# Lot Area             int64
# Street               int64
# Alley                int64
# Lot Shape            int64
# Land Contour         int64
# Neighborhood         int64
# Condition 1          int64
# Condition 2          int64
# Bldg Type            int64
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style           int64
# Exterior 1st         int64
# Exterior 2nd         int64
# Mas Vnr Type       float64
# Mas Vnr Area       float64
# Exter Qual           int64
# Exter Cond           int64
# Foundation           int64
# Bsmt Qual            int64
# Bsmt Cond            int64
# Bsmt Exposure        int64
# BsmtFin Type 1     float64
# BsmtFin SF 1       float64
# BsmtFin SF 2       float64
# Total Bsmt SF      float64
# Heating              int64
# Heating QC           int64
# Central Air          int64
# ...

# %%
#List down categorical features
def categorical_features(df):
    lst=[]
    for col in df.columns:
        if (df[col].dtype == 'object'):
            lst.append(col)
    return lst

cat_featuress = categorical_features(train_dropped_lasso_df)

# %%
cat_featuress
# Out:
# []

# %%
train_dropped_lasso_df.dtypes
# Out:
# PID                  int64
# MS SubClass          int64
# MS Zoning            int64
# Lot Area             int64
# Street               int64
# Alley                int64
# Lot Shape            int64
# Land Contour         int64
# Neighborhood         int64
# Condition 1          int64
# Condition 2          int64
# Bldg Type            int64
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style           int64
# Exterior 1st         int64
# Exterior 2nd         int64
# Mas Vnr Type       float64
# Mas Vnr Area       float64
# Exter Qual           int64
# Exter Cond           int64
# Foundation           int64
# Bsmt Qual            int64
# Bsmt Cond            int64
# Bsmt Exposure        int64
# BsmtFin Type 1     float64
# BsmtFin SF 1       float64
# BsmtFin SF 2       float64
# Total Bsmt SF      float64
# Heating              int64
# Heating QC           int64
# Central Air          int64
# ...

# %%
#Try to model features after dropping the above columns
X = train_dropped_lasso_df.loc[:, train_dropped_lasso_df.columns != 'SalePrice']
y = train_dropped_lasso_df[['SalePrice']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
lr2 = LinearRegression()
lr2.fit(X_train, y_train)
lr2.score(X_train, y_train)
preds_lr_model_2 = lr2.predict(X_test)
preds_lr_train_model_2 = lr2.predict(X_train)
print(f'R2 on test set(Linear Regression model 2): {lr2.score(X_test, y_test)}')
print(f'RMSE on train set (Linear Regression Model 2): {sqrt(mean_squared_error(y_train, preds_lr_train_model_2))}')
print(f'RMSE on test set (Linear Regression Model 2): {sqrt(mean_squared_error(y_test, preds_lr_model_2))}')
RMSE_train_2 = sqrt(mean_squared_error(y_train, preds_lr_train_model_2))
RMSE_test_2 = sqrt(mean_squared_error(y_test, preds_lr_model_2))
# Out:
# R2 on test set(Linear Regression model 2): 0.9025591165832592
# RMSE on train set (Linear Regression Model 2): 24401.460914148658
# RMSE on test set (Linear Regression Model 2): 25561.57117680452

# %%
cross_val_score(lr, X_train, y_train, cv=5)
# Out:
# array([0.89924305, 0.8732282 , 0.89466813, 0.90559179, 0.86912435])

# %% [markdown]
# <h4> <font color = 'Maroon'> Model 2 - Lasso Regression

# %%
Xtrain_s = ss.fit_transform(X_train)
Xtest_s = ss.transform(X_test)
optimal_lasso_model_2 = LassoCV(n_alphas=500, cv=10, verbose=1)
optimal_lasso_model_2.fit(Xtrain_s, y_train)

print (optimal_lasso_model_2.alpha_)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
lasso2 = Lasso(alpha=optimal_lasso_model_2.alpha_)
lasso2.fit(Xtrain_s, y_train)
lasso_pred_model_2_optimised = lasso2.predict(Xtest_s)
lasso_pred_model_2_optimised_train = lasso2.predict(Xtrain_s)
R_squared = r2_score(lasso_pred_model_2_optimised, y_test)
print('Test R-squared score (Lasso) :', R_squared)
print(f'RMSE on train set(Lasso Regression Model 2): {sqrt(mean_squared_error(y_train, lasso_pred_model_2_optimised_train))}')
print(f'RMSE on test set(Lasso Regression Model 2): {sqrt(mean_squared_error(y_test, lasso_pred_model_2_optimised))}')
RMSE_train_lasso_2 = sqrt(mean_squared_error(y_train, lasso_pred_model_2_optimised_train))
RMSE_test_lasso_2 = sqrt(mean_squared_error(y_test, lasso_pred_model_2_optimised))
# Out:
# Test R-squared score (Lasso) : 0.884598729939929
# RMSE on train set(Lasso Regression Model 2): 24408.41178192893
# RMSE on test set(Lasso Regression Model 2): 25530.561227578455

# %% [markdown]
# <h4> <font color = 'Maroon'> Model 2 - Ridge Regression

# %%
optimal_ridge_model_2 = RidgeCV()
optimal_ridge_model_2.fit(Xtrain_s, y_train)

print (optimal_ridge_model_2.alpha_)
# Out:
# 10.0

# %%
ridge2 = Ridge(alpha=optimal_lasso_model_2.alpha_)
ridge2.fit(Xtrain_s, y_train)
ridge_pred_model_2_optimised = ridge2.predict(Xtest_s)
ridge_pred_model_2_optimised_train = ridge2.predict(Xtrain_s)
R_squared = r2_score(ridge_pred_model_2_optimised, y_test)
print('Test R-squared score (Ridge) :', R_squared)
print(f'RMSE on train set(Ridge Regression Model 2): {sqrt(mean_squared_error(y_train, ridge_pred_model_2_optimised_train))}')
print(f'RMSE on test set(Ridge Regression Model 2): {sqrt(mean_squared_error(y_test, ridge_pred_model_2_optimised))}')
RMSE_train_ridge_2 = sqrt(mean_squared_error(y_train, ridge_pred_model_2_optimised_train))
RMSE_test_ridge_2 = sqrt(mean_squared_error(y_test, ridge_pred_model_2_optimised))
# Out:
# Test R-squared score (Ridge) : 0.8809448647498149
# RMSE on train set(Ridge Regression Model 2): 24498.579914875198
# RMSE on test set(Ridge Regression Model 2): 25714.30223561302

# %%
train_dropped_lasso_df.columns
# Out:
# Index(['PID', 'MS SubClass', 'MS Zoning', 'Lot Area', 'Street', 'Alley',
#        'Lot Shape', 'Land Contour', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remod/Add', 'Roof Style', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bedroom AbvGr', 'Kitchen AbvGr',
#        'Kitchen Qual', 'TotRms AbvGrd', 'Functional', 'Fireplace Qu',
#        'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Screen Porch', 'Misc Val', 'Building Age', 'Sale Type', 'SalePrice'],
#       dtype='object')

# %%
train_dropped_lasso_df.shape
# Out:
# (2049, 57)

# %% [markdown]
# Above 57 features are retained as a result of Model 2 optimisation. It can be seen that almost all of the features with high correlation as previously mentioned are included in the final feature selection

# %% [markdown]
# <h3> <font color = 'Maroon'> Model 3 - Drop columns after Feature Engineering

# %% [markdown]
# Criteria for Model 3 Features to drop:
# 1. Variables with more than 70% threshold of counts in each of the category
# 2. High Colinearity variables (>0.75) and drop variables with lower correlation to Sale Price
# 3. Low correlation variables to Sale Price (<0.4)

# %% [markdown]
# Refer to the countplots during EDA and data visualisation, those variables with more than 70% threshold of counts by each of the category will be dropped

# %%
train_dropped_70_df = train_df.drop(['MS Zoning','Street','Alley','Land Contour','Utilities','Lot Config','Land Slope','Condition 1','Condition 2','Bldg Type','Roof Style','Roof Matl','Exter Cond', 'Bsmt Cond', 'BsmtFin Type 2', 'Heating','Central Air', 'Electrical','Functional','Garage Qual','Garage Cond','Paved Drive','Pool QC','Fence','Misc Feature','Sale Type'], axis=1)

# %%
train_dropped_70_df_corr = train_dropped_70_df.corr()

# %% [markdown]
# Checking for high colinearity variables to check if it is possible to drop the variable that has lower correlation to SalePrice

# %%
cut_off = 0.75
high_corrs = train_dropped_70_df_corr[train_dropped_70_df_corr.abs() > cut_off][train_dropped_70_df_corr.abs() != 1].unstack().dropna().to_dict()
high_corrs = pd.Series(high_corrs, index = high_corrs.keys())
high_corrs = high_corrs.reset_index()
high_corrs = pd.DataFrame(high_corrs)
high_corrs.columns = ['Feature_1', 'Feature_2','Correlations']
high_corrs['Correlations'] = high_corrs['Correlations'].drop_duplicates(keep ='first')
high_corrs = high_corrs.dropna().sort_values(by = 'Correlations', ascending = False)
high_corrs
# Out:
#         Feature_1      Feature_2  Correlations
# 11    Garage Cars    Garage Area      0.897029
# 9      Fireplaces   Fireplace Qu      0.860785
# 3    Exterior 1st   Exterior 2nd      0.851266
# 7     Gr Liv Area  TotRms AbvGrd      0.812129
# 1    Overall Qual      SalePrice      0.803462
# 5   Total Bsmt SF     1st Flr SF      0.790580
# 0              Id        Yr Sold     -0.975765
# 2      Year Built   Building Age     -0.999055

# %%
train_dropped_70_df.drop(['Garage Cars', 'Fireplaces', 'Exterior 1st', 'TotRms AbvGrd', '1st Flr SF', 'Year Built' ,'Yr Sold'], axis =1, inplace = True)

# %%
#Checking for variables to drop (those that have < 0.4 correlation to SalePrice)
corr_target1 = train_dropped_70_df_corr['SalePrice'] < 0.4
corr_target2 = train_dropped_70_df_corr['SalePrice'] > -0.4
corr_target1[corr_target1 == True].index
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'Lot Frontage', 'Lot Area', 'Lot Shape',
#        'Neighborhood', 'House Style', 'Overall Cond', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Foundation', 'BsmtFin Type 1',
#        'BsmtFin SF 2', 'Bsmt Unf SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Bsmt Full Bath', 'Bsmt Half Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Garage Yr Blt', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val',
#        'Mo Sold', 'Building Age', 'Yr Sold'],
#       dtype='object')

# %%
corr_target2[corr_target2 == True].index
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'Lot Frontage', 'Lot Area', 'Lot Shape',
#        'Neighborhood', 'House Style', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remod/Add', 'Exterior 1st', 'Exterior 2nd',
#        'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual', 'Bsmt Qual',
#        'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin SF 2',
#        'Bsmt Unf SF', 'Total Bsmt SF', 'Heating QC', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Fireplaces',
#        'Fireplace Qu', 'Garage Type', 'Garage Yr Blt', 'Garage Finish',
#        'Garage Cars', 'Garage Area', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val',
#        'Mo Sold', 'Yr Sold', 'SalePrice'],
#       dtype='object')

# %%
train_dropped_70_df.drop(['PID', 'MS SubClass', 'Lot Frontage', 'Lot Area', 'Lot Shape',
       'Neighborhood', 'House Style', 'Overall Cond',
       'Exterior 2nd', 'Mas Vnr Type', 'Foundation', 'BsmtFin Type 1',
       'BsmtFin SF 2', 'Bsmt Unf SF', '2nd Flr SF', 'Low Qual Fin SF',
       'Bsmt Full Bath', 'Bsmt Half Bath', 'Half Bath', 'Bedroom AbvGr',
       'Kitchen AbvGr', 'Garage Yr Blt', 'Wood Deck SF', 'Open Porch SF',
       'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val',
       'Mo Sold'], axis =1, inplace = True)

# %%
train_dropped_70_df.columns
# Out:
# Index(['Id', 'Overall Qual', 'Year Remod/Add', 'Mas Vnr Area', 'Exter Qual',
#        'Bsmt Qual', 'Bsmt Exposure', 'BsmtFin SF 1', 'Total Bsmt SF',
#        'Heating QC', 'Gr Liv Area', 'Full Bath', 'Kitchen Qual',
#        'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Area',
#        'Building Age', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# <h4> <font color = 'Maroon'> Model 3 - Linear Regression

# %%
#Try to model features after dropping the above columns
X = train_dropped_70_df.loc[:, train_dropped_70_df.columns != 'SalePrice']
y = train_dropped_70_df[['SalePrice']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
lr3 = LinearRegression()
lr3.fit(X_train, y_train)
lr3.score(X_train, y_train)
preds_lr_model_3 = lr3.predict(X_test)
preds_lr_train_model_3 = lr3.predict(X_train)
print(f'R2 on test set(Linear Regression model 3): {lr3.score(X_test, y_test)}')
print(f'RMSE on train set (Linear Regression Model 3): {sqrt(mean_squared_error(y_train, preds_lr_train_model_3))}')
print(f'RMSE on test set(Linear Regression model 3): {sqrt(mean_squared_error(y_test, preds_lr_model_3))}')
RMSE_train_3 = sqrt(mean_squared_error(y_train, preds_lr_train_model_3))
RMSE_test_3 = sqrt(mean_squared_error(y_test, preds_lr_model_3))
# Out:
# R2 on test set(Linear Regression model 3): 0.8786853953828259
# RMSE on train set (Linear Regression Model 3): 28071.10392787446
# RMSE on test set(Linear Regression model 3): 28521.573545273255

# %%
cross_val_score(lr, X_train, y_train, cv=5)
# Out:
# array([0.87961059, 0.85149911, 0.86379958, 0.88103119, 0.84601499])

# %% [markdown]
# <h4> <font color = 'Maroon'> Model 3 - Lasso Regression

# %%
ss = StandardScaler()

Xtrain_s = ss.fit_transform(X_train)
Xtest_s = ss.transform(X_test)
optimal_lasso_model_3 = LassoCV(n_alphas=500, cv=10, verbose=1)
optimal_lasso_model_3.fit(Xtrain_s, y_train)

print (optimal_lasso_model_3.alpha_)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
lasso3 = Lasso(alpha=optimal_lasso_model_3.alpha_)
lasso3.fit(Xtrain_s, y_train)
lasso_pred_model_3_optimised = lasso3.predict(Xtest_s)
lasso_pred_model_3_optimised_train = lasso3.predict(Xtrain_s)
R_squared = r2_score(lasso_pred_model_3_optimised, y_test)
print('Test R-squared score (Lasso) :', R_squared)
print(f'RMSE on train set(Lasso Regression Model 3): {sqrt(mean_squared_error(y_train, lasso_pred_model_3_optimised_train))}')
print(f'RMSE on test set(Lasso Regression Model 3): {sqrt(mean_squared_error(y_test, lasso_pred_model_3_optimised))}')
RMSE_train_lasso_3 = sqrt(mean_squared_error(y_train, lasso_pred_model_3_optimised_train))
RMSE_test_lasso_3 = sqrt(mean_squared_error(y_test, lasso_pred_model_3_optimised))
# Out:
# Test R-squared score (Lasso) : 0.849748013872545
# RMSE on train set(Lasso Regression Model 3): 28073.188037598524
# RMSE on test set(Lasso Regression Model 3): 28515.111913941073

# %% [markdown]
# <h4> <font color = 'Maroon'> Model 3 - Ridge Regression

# %%
optimal_ridge_model_3 = RidgeCV()
optimal_ridge_model_3.fit(Xtrain_s, y_train)

print (optimal_ridge_model_3.alpha_)
# Out:
# 10.0

# %%
ridge3 = Ridge(alpha=optimal_ridge_model_3.alpha_)
ridge3.fit(Xtrain_s, y_train)
ridge_pred_model_3_optimised = ridge3.predict(Xtest_s)
ridge_pred_model_3_optimised_train = ridge3.predict(Xtrain_s)
R_squared = r2_score(ridge_pred_model_3_optimised, y_test)
print('Test R-squared score (Ridge Regression Model 3) :', R_squared)
print(f'RMSE on train set(Ridge Regression Model 3): {sqrt(mean_squared_error(y_train, ridge_pred_model_3_optimised_train))}')
print(f'RMSE on test set(Ridge Regression Model 3): {sqrt(mean_squared_error(y_test, ridge_pred_model_3_optimised))}')
RMSE_train_ridge_3 = sqrt(mean_squared_error(y_train, ridge_pred_model_3_optimised_train))
RMSE_test_ridge_3 = sqrt(mean_squared_error(y_test, ridge_pred_model_3_optimised))
# Out:
# Test R-squared score (Ridge Regression Model 3) : 0.8496307002140626
# RMSE on train set(Ridge Regression Model 3): 28073.046195307452
# RMSE on test set(Ridge Regression Model 3): 28513.820920652866

# %%
train_dropped_70_df.columns
# Out:
# Index(['Id', 'Overall Qual', 'Year Remod/Add', 'Mas Vnr Area', 'Exter Qual',
#        'Bsmt Qual', 'Bsmt Exposure', 'BsmtFin SF 1', 'Total Bsmt SF',
#        'Heating QC', 'Gr Liv Area', 'Full Bath', 'Kitchen Qual',
#        'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Area',
#        'Building Age', 'SalePrice'],
#       dtype='object')

# %%
train_dropped_70_df.shape
# Out:
# (2049, 19)

# %% [markdown]
# Based on Model 3, only 19 features are retained as shown above

# %% [markdown]
# <h5><font color = 'Maroon'> Summary of All Models RMSE

# %%
model_rmse_df = pd.DataFrame()
model_rmse_df['Models'] = ['Linear Regression', 'Lasso Regression', 'Ridge Regression']
model_rmse_df['Training Set RMSE Model 1'] = [RMSE_train_1, RMSE_train_lasso_1, RMSE_train_ridge_1 ]
model_rmse_df['Test Set RMSE Model 1'] = [RMSE_test_1, RMSE_test_lasso_1, RMSE_test_ridge_1]
model_rmse_df['Training Set RMSE Model 2'] = [RMSE_train_2, RMSE_train_lasso_2, RMSE_train_ridge_2]
model_rmse_df['Test Set RMSE Model 2'] = [RMSE_test_2, RMSE_test_lasso_2, RMSE_test_ridge_2]
model_rmse_df['Training Set RMSE Model 3'] = [RMSE_train_3, RMSE_train_lasso_3, RMSE_train_ridge_3]
model_rmse_df['Test Set RMSE Model 3'] = [RMSE_test_3, RMSE_test_lasso_3, RMSE_test_ridge_3]
model_rmse_df
# Out:
#               Models  Training Set RMSE Model 1  Test Set RMSE Model 1  \
# 0  Linear Regression               24302.914044           25570.676220
# 1   Lasso Regression               24477.559941           25496.935323
# 2   Ridge Regression               24317.722749           25528.915560
#
#    Training Set RMSE Model 2  Test Set RMSE Model 2  \
# 0               24401.460914           25561.571177
# 1               24408.411782           25530.561228
# 2               24498.579915           25714.302236
#
#    Training Set RMSE Model 3  Test Set RMSE Model 3
# 0               28071.103928           28521.573545
# 1               28073.188038           28515.111914
# 2               28073.046195           28513.820921

# %% [markdown]
# Based on all 3 models, it can be inferred that:
# - All 3 models test data have higher RMSE than those in training data. This means that models are slightly overfitting and cause them to perform slighty worse on the test data
# - Referring to test set for all models, lasso regression has been the best performer comparing to other regression models, suggesting that data is not completely linear. Also, lasso regression is able to cover more ranges compared to ridge as the size of coefficients can go close to zero. This will reduce the effect of the noisy columns on the model
# - On test set, regularization models are better performers to avoid overfitting as from linear regression. It can be seen that the value of (Test set RMSE - Training set RMSE) for regularization models are tighter than the value of (Test set RMSE - Training set RMSE) in linear regression model

# %% [markdown]
# Model 1 is a model with all features included. As features are dropped as shown in model 2 and model 3, the RMSE is slightly higher. Dropping features can reduce the accuracy of the SalePrice prediction as the predictor columns are dropped.

# %% [markdown]
# For prediction purposes, i will use Model 2 of Lasso Regression as this model has the lower RMSE compared to model 3.
#
# While model 1 has slightly lower RMSE compared to the rest of the model, it might need longer time to run the model especially if datasets have too many features.
# Also, if test_csv does not have a lot of features, it is necessary to create many new columns and fill in with some values which can induce imputing mistakes or cause the prediction to be more distorted

# %%
train_dropped_lasso_df.columns
# Out:
# Index(['PID', 'MS SubClass', 'MS Zoning', 'Lot Area', 'Street', 'Alley',
#        'Lot Shape', 'Land Contour', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remod/Add', 'Roof Style', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bedroom AbvGr', 'Kitchen AbvGr',
#        'Kitchen Qual', 'TotRms AbvGrd', 'Functional', 'Fireplace Qu',
#        'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Screen Porch', 'Misc Val', 'Building Age', 'Sale Type', 'SalePrice'],
#       dtype='object')

# %%
train_dropped_lasso_df.shape
# Out:
# (2049, 57)

# %% [markdown]
# Final features include 57 features above

# %% [markdown]
# Pick Lasso Model 2 to try on test.csv file

# %% [markdown]
# ## <font color = 'Maroon'> Test Set Data Import and Preprocessing

# %%
test_df = pd.read_csv('../datasets/test.csv')

# %%
test_df['MS SubClass'] = test_df['MS SubClass'].astype(str)
pd.set_option('display.max_rows', 85)
test_df.dtypes
# Out:
# Id                   int64
# PID                  int64
# MS SubClass         object
# MS Zoning           object
# Lot Frontage       float64
# Lot Area             int64
# Street              object
# Alley               object
# Lot Shape           object
# Land Contour        object
# Utilities           object
# Lot Config          object
# Land Slope          object
# Neighborhood        object
# Condition 1         object
# Condition 2         object
# Bldg Type           object
# House Style         object
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style          object
# Roof Matl           object
# Exterior 1st        object
# Exterior 2nd        object
# Mas Vnr Type        object
# Mas Vnr Area       float64
# Exter Qual          object
# Exter Cond          object
# Foundation          object
# Bsmt Qual           object
# Bsmt Cond           object
# Bsmt Exposure       object
# ...

# %%
print(test_df.shape)
# Out:
# (878, 80)

# %%
#Check for null values
test_null_df =test_df.isnull().sum()/878*100
test_null_df.sort_values(ascending = False)
# Out:
# Pool QC            99.544419
# Misc Feature       95.330296
# Alley              93.394077
# Fence              80.410023
# Fireplace Qu       48.063781
# Lot Frontage       18.223235
# Garage Cond         5.125285
# Garage Qual         5.125285
# Garage Yr Blt       5.125285
# Garage Finish       5.125285
# Garage Type         5.011390
# Bsmt Exposure       2.847380
# BsmtFin Type 1      2.847380
# Bsmt Qual           2.847380
# BsmtFin Type 2      2.847380
# Bsmt Cond           2.847380
# Mas Vnr Area        0.113895
# Mas Vnr Type        0.113895
# Electrical          0.113895
# Overall Cond        0.000000
# Exter Qual          0.000000
# Exter Cond          0.000000
# Foundation          0.000000
# Exterior 2nd        0.000000
# Exterior 1st        0.000000
# Roof Matl           0.000000
# Roof Style          0.000000
# Year Remod/Add      0.000000
# Year Built          0.000000
# Sale Type           0.000000
# Overall Qual        0.000000
# House Style         0.000000
# ...

# %%
test_consist_null = test_null_df > 0
test_consist_null_df = test_null_df[test_consist_null]
test_consist_null_ordered_df = test_consist_null_df.sort_values()

fig = plt.figure(figsize=(30,20))
test_consist_null_ordered_df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
test_consist_null_ordered_df.sort_values(ascending = False)
# Out:
# Pool QC           99.544419
# Misc Feature      95.330296
# Alley             93.394077
# Fence             80.410023
# Fireplace Qu      48.063781
# Lot Frontage      18.223235
# Garage Qual        5.125285
# Garage Cond        5.125285
# Garage Finish      5.125285
# Garage Yr Blt      5.125285
# Garage Type        5.011390
# BsmtFin Type 2     2.847380
# BsmtFin Type 1     2.847380
# Bsmt Exposure      2.847380
# Bsmt Cond          2.847380
# Bsmt Qual          2.847380
# Mas Vnr Area       0.113895
# Mas Vnr Type       0.113895
# Electrical         0.113895
# dtype: float64

# %%
categorical_test_none = test_df[['Pool QC', 'Misc Feature', 'Alley', 'Fence', 'Fireplace Qu','Garage Cond', 'Garage Qual', 'Garage Finish', 'Garage Type','Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2', 'Bsmt Cond', 'Bsmt Qual', 'Mas Vnr Type']]

for features in categorical_none:
    test_df[features] = test_df[features].fillna("None")

# %%
#Trying to use iterative imputer to Lot Frontage null values
lot_frontage_test_missing_df = test_df[['Lot Area','Lot Frontage']]
impute_test_lot_frontage = IterativeImputer(estimator = LinearRegression(),random_state = 42,skip_complete=True)

lot_frontage_test_missing_imputed = impute_test_lot_frontage.fit_transform(lot_frontage_test_missing_df)
lot_frontage_test_missing_imputed_df = pd.DataFrame(lot_frontage_test_missing_imputed, columns = lot_frontage_test_missing_df.columns)

test_df["Lot Frontage"] = lot_frontage_test_missing_imputed_df["Lot Frontage"]

# %%
test_df[["Id","Lot Frontage", 'Lot Area']]
# Out:
#        Id  Lot Frontage  Lot Area
# 0    2658     69.000000      9142
# 1    2718     69.308020      9662
# 2    2414     58.000000     17104
# 3    1989     60.000000      8520
# 4     625     69.127591      9500
# ..    ...           ...       ...
# 873  1662     80.000000      8000
# 874  1234     90.000000     14670
# 875  1373     55.000000      8250
# 876  1672     60.000000      9000
# 877  1939     70.000000      8400
#
# [878 rows x 3 columns]

# %%
#Encode Mas Vnr Type to check for further correlation
test_df['Mas Vnr Type'] = test_df['Mas Vnr Type'].map({'None' :0,'Stone' :1, 'CBlock' :2, 'BrkFace' : 3, 'BrkCmn' :4})

# %%
#Impute Mas Vnr Area
mas_vnr_test_missing_df = test_df[['Mas Vnr Type','Mas Vnr Area']]
impute_mas_test_vnr = IterativeImputer()

it_imp_mas_vnr_test_missing_imputed = impute_mas_test_vnr.fit_transform(mas_vnr_test_missing_df)
it_imp_mas_vnr_missing_test_imputed_df = pd.DataFrame(it_imp_mas_vnr_test_missing_imputed , columns = mas_vnr_test_missing_df.columns)

it_imp_mas_vnr_missing_test_imputed_df[['Mas Vnr Type','Mas Vnr Area']] =it_imp_mas_vnr_missing_test_imputed_df[['Mas Vnr Type','Mas Vnr Area']].round()

test_df[['Mas Vnr Type','Mas Vnr Area']] = it_imp_mas_vnr_missing_test_imputed_df[['Mas Vnr Type','Mas Vnr Area']]

# %%
#Add Features -> Yr Sold - Year Built = Building Age
test_df.insert(79,'Building Age', test_df['Yr Sold'] - test_df['Year Built'])

# %%
#Impute Garage Yr Blt -> Empty values mean no garage
test_df['Garage Yr Blt'] = test_df['Garage Yr Blt'].fillna(0)

# %%
#Fill in Electrical Null values with mode...
test_df['Electrical'] = test_df['Electrical'].fillna(test_df['Electrical'].mode()[0])

# %%
test_df['BsmtFin Type 1'] = test_df['BsmtFin Type 1'].map({'None' :0,'Unf' :1, 'LwQ' :2, 'Rec' :3, 'BLQ' :4,'ALQ' :5 ,'GLQ' :6})
test_df['BsmtFin Type 2'] = test_df['BsmtFin Type 2'].map({'None' :0,'Unf' :1, 'LwQ' :2, 'Rec' :3, 'BLQ' :4,'ALQ' :5 ,'GLQ' :6})
test_df['Garage Type'] = test_df['Garage Type'].map({'None' :0,'Detchd' :1, 'CarPort' :2, 'BuiltIn' : 3, 'Basment' :4, 'Attchd': 5, '2Types': 6})
test_df['Street'] = test_df['Street'].map({'Grvl':1,'Pave' :2})
test_df['Alley'] = test_df['Alley'].map({'None': 0,'Grvl':1,'Pave' :2})
test_df['Lot Shape'] = test_df['Lot Shape'].map({'IR3': 1,'IR2':2,'IR1' :3, 'Reg' :4})
test_df['Land Contour'] = test_df['Land Contour'].map({'Low': 1,'HLS':2,'Bnk' :3, 'Lvl':4})
test_df['Utilities'] = test_df['Utilities'].map({'ELO': 1,'NoSeWa':2,'NoSewr' :3, 'AllPub':4})
test_df['Lot Config'] = test_df['Lot Config'].map({'FR3': 1,'FR2':2,'CulDSac' :3, 'Corner':4, 'Inside': 5})
test_df['Land Slope'] = test_df['Land Slope'].map({'Sev': 1,'Mod':2,'Gtl' :3})
test_df['Neighborhood'] = test_df['Neighborhood'].map({'Veenker': 1,'Timber':2,'StoneBr' :3,'Somerst' :4,'SawyerW' :5,'Sawyer' :6,'SWISU' :7,'OldTown' :8,'NWAmes' :9,'NridgHt' :10,'NPkVill' :11,'NoRidge' :12,'NAmes' :13,'Mitchel' :14,'MeadowV' :15,'Landmrk' :16,'IDOTRR' :17,'GrnHill' :18,'Greens' :19,'Gilbert' :20,'Edwards' :21,'Crawfor' :22,'CollgCr' :23,'ClearCr' :24,'BrkSide' :25,'BrDale' :26,'Blueste' :27,'Blmngtn' :28})
test_df['Condition 1'] = test_df['Condition 1'].map({'RRAe': 1,'RRNe':2,'PosA' :3,'PosN': 4,'RRAn': 5,'RRNn': 6,'Norm': 7,'Feedr': 8,'Artery': 9})
test_df['Condition 2'] = test_df['Condition 2'].map({'RRAe': 1,'RRNe':2,'PosA' :3,'PosN': 4,'RRAn': 5,'RRNn': 6,'Norm': 7,'Feedr': 8,'Artery': 9})
test_df['Bldg Type'] = test_df['Bldg Type'].map({'Twnhs': 1,'TwnhsE':2,'Duplex' :3,'2fmCon':4, '1Fam': 5})
test_df['House Style'] = test_df['House Style'].map({'SLvl': 1,'SFoyer':2,'2.5Unf' :3,'2.5Fin':4, '2Story': 5,'1.5Unf': 6,'1.5Fin': 7,'1Story': 8})
test_df['Roof Style'] = test_df['Roof Style'].map({'Shed': 1,'Mansard':2,'Hip' :3,'Gambrel':4, 'Gable': 5, 'Flat': 6})
test_df['Roof Matl'] = test_df['Roof Matl'].map({'WdShngl': 1,'WdShake':2,'Tar&Grv' :3,'Roll':4, 'Metal': 5,'Membran': 6,'CompShg': 7,'ClyTile': 8})
test_df['Exterior 1st'] = test_df['Exterior 1st'].map({'WdShing': 1,'Wd Sdng':2,'VinylSd' :3,'Stucco':4, 'Stone': 5,'Plywood': 6,'MetalSd': 7,'ImStucc': 8,'HdBoard': 9,'CemntBd': 10,'CBlock': 11,'BrkFace': 12,'BrkComm': 13,'AsphShn': 14,'AsbShng': 15, 'PreCast': 16})
test_df['Exterior 2nd'] = test_df['Exterior 2nd'].map({'Wd Shng': 1,'Wd Sdng':2,'VinylSd' :3,'Stucco':4, 'Stone': 5,'Plywood': 6,'MetalSd': 7,'ImStucc': 8,'HdBoard': 9,'CmentBd': 10,'CBlock': 11,'BrkFace': 12,'Brk Cmn': 13,'AsphShn': 14,'AsbShng': 15, 'PreCast': 16, 'Other': 17})
test_df['Exter Qual'] = test_df['Exter Qual'].map({'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
test_df['Exter Cond'] = test_df['Exter Cond'].map({'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
test_df['Foundation'] = test_df['Foundation'].map({'Wood': 1,'Stone':2,'Slab' :3,'PConc':4, 'CBlock': 5, 'BrkTil': 6})
test_df['Bsmt Qual'] = test_df['Bsmt Qual'].map({'None': 0,'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
test_df['Bsmt Cond'] = test_df['Bsmt Cond'].map({'None': 0,'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
test_df['Bsmt Exposure'] = test_df['Bsmt Exposure'].map({'None': 0,'No': 1,'Mn':2,'Av' :3,'Gd':4})
test_df['Heating'] = test_df['Heating'].map({'Wall': 1,'OthW': 2,'Grav':3,'GasW' :4,'GasA':5,'Floor':6})
test_df['Heating QC'] = test_df['Heating QC'].map({'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
test_df['Central Air'] = test_df['Central Air'].map({'N':0,'Y' :1})
test_df['Electrical'] = test_df['Electrical'].map({'Mix': 1,'FuseP':2,'FuseF' :3,'FuseA':4, 'SBrkr': 5})
test_df['Kitchen Qual'] = test_df['Kitchen Qual'].map({'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
test_df['Functional'] = test_df['Functional'].map({'Sal': 1,'Sev':2,'Maj2' :3,'Maj1':4, 'Mod': 5,'Min2': 6,'Min1': 7,'Typ': 8})
test_df['Fireplace Qu'] = test_df['Fireplace Qu'].map({'None': 0,'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
test_df['Garage Finish'] = test_df['Garage Finish'].map({'None': 0,'Unf': 1,'RFn':2,'Fin' :3})
test_df['Garage Qual'] = test_df['Garage Qual'].map({'None': 0,'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
test_df['Garage Cond'] = test_df['Garage Cond'].map({'None': 0,'Po': 1,'Fa':2,'TA' :3,'Gd':4, 'Ex': 5})
test_df['Paved Drive'] = test_df['Paved Drive'].map({'N': 1,'P': 2,'Y':3})
test_df['Pool QC'] = test_df['Pool QC'].map({'None': 0,'Fa':1,'TA' :2,'Gd':3, 'Ex': 4})
test_df['Fence'] = test_df['Fence'].map({'None': 0,'MnWw': 1,'GdWo':2,'MnPrv' :3,'GdPrv':4})
test_df['Misc Feature'] = test_df['Misc Feature'].map({'None': 0,'TenC': 1,'Shed':2,'Othr' :3,'Gar2':4,'Elev':5})
test_df['Sale Type'] = test_df['Sale Type'].map({'Oth': 1,'ConLD':2,'ConLI' :3,'ConLw':4,'Con':5,'COD':6,'New':7,'CWD':8,'WD ':9,'VWD':10})
test_df['MS Zoning'] = test_df['MS Zoning'].map({'RM': 1,'RL' :2,'RH':3,'I (all)':4,'FV':5,'C (all)':6,'A (agr)':7})
test_df['MS SubClass'] = test_df['MS SubClass'].map({'190': 1,'180':2,'160' :3,'150':4,'120':5,'90':6,'85':7,'80':8, '75': 9,'70': 10, '60': 11, '50': 12, '45': 13, '40': 14, '30': 15, '20': 16})

# %%
test_df.isnull().sum()
# Out:
# Id                 0
# PID                0
# MS SubClass        0
# MS Zoning          0
# Lot Frontage       0
# Lot Area           0
# Street             0
# Alley              0
# Lot Shape          0
# Land Contour       0
# Utilities          0
# Lot Config         0
# Land Slope         0
# Neighborhood       0
# Condition 1        0
# Condition 2        0
# Bldg Type          0
# House Style        0
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Roof Style         0
# Roof Matl          0
# Exterior 1st       0
# Exterior 2nd       0
# Mas Vnr Type       0
# Mas Vnr Area       0
# Exter Qual         0
# Exter Cond         0
# Foundation         0
# Bsmt Qual          0
# Bsmt Cond          0
# Bsmt Exposure      0
# BsmtFin Type 1     0
# BsmtFin SF 1       0
# BsmtFin Type 2     0
# BsmtFin SF 2       0
# Bsmt Unf SF        0
# Total Bsmt SF      0
# Heating            0
# Heating QC         0
# Central Air        0
# ...

# %%
test_dropped_lasso_df = test_df.drop(coefficient_lasso_cond_to_drop, axis = 1)

# %%
test_dropped_lasso_df.columns
# Out:
# Index(['PID', 'MS SubClass', 'MS Zoning', 'Lot Area', 'Street', 'Alley',
#        'Lot Shape', 'Land Contour', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remod/Add', 'Roof Style', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bedroom AbvGr', 'Kitchen AbvGr',
#        'Kitchen Qual', 'TotRms AbvGrd', 'Functional', 'Fireplace Qu',
#        'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Screen Porch', 'Misc Val', 'Building Age', 'Sale Type'],
#       dtype='object')

# %%
best_features = test_dropped_lasso_df.columns
best_features
# Out:
# Index(['PID', 'MS SubClass', 'MS Zoning', 'Lot Area', 'Street', 'Alley',
#        'Lot Shape', 'Land Contour', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remod/Add', 'Roof Style', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bedroom AbvGr', 'Kitchen AbvGr',
#        'Kitchen Qual', 'TotRms AbvGrd', 'Functional', 'Fireplace Qu',
#        'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Screen Porch', 'Misc Val', 'Building Age', 'Sale Type'],
#       dtype='object')

# %% [markdown]
# ## <font color = 'Maroon'> Test Set House Sale Price Prediction

# %%
X = test_dropped_lasso_df.loc[:]
Xs = ss.fit_transform(X)

# %%
prediction = lasso2.predict(Xs)

# %%
#Submission
submission = pd.DataFrame()
submission['Id'] = test_df['Id']
submission['SalePrice'] = prediction
submission.head()
# Out:
#      Id      SalePrice
# 0  2658  152153.332101
# 1  2718  149675.264599
# 2  2414  218205.249364
# 3  1989  115829.454924
# 4   625  176263.833934

# %%
#Export the File
submission.to_csv('../datasets/project2_submission_dataset_nelson.csv',index=False)

# %% [markdown]
# ## <font color = 'Maroon'> Summary and Conclusion

# %% [markdown]
# Below are the key takeaways based om the analysis above:
# - Based on some observations, house style with Overall Qual, Gr Liv Area, Building Age, Total Bsmt SF, 1st Flr SF,higher counts of storeys, basement quality, exposure, heating quality have relatively moderate to high correlation to Sale price
# - 3 methods (All features, features with relatively strong lasso coefficient, and features after feature engineering) were fitted to 3 regression machine models (Linear, Lasso and Ridge regression) and were tested to compare their performances . Generally, regularization models (Lasso and Ridge) reduce the overfitting as compared to Linear Regression as they have lower RMSE
# - Method 2 with lasso modelling has the best model RMSE performance of 25530.56 on test set in training data. Therefore, method 2 lasso modelling were chosen as the model to predict the house sale price
# - Achieved a relatively well low bias public score of 29240.47768 and private score of 23019.72643 once fitted to the kaggle DSI-US-11 Project 2 Regression Challenge
# - There are a total of 57 features for the final model and top 5 features will be Overall Qual, Gr Live area, exter qual, kitchen qual and total bsmt SF
#
#
# More importantly, clients may want to invest a certain amount of money to improve the overall condition or improve the ground living area as well as primary features such as exterior conditions,kitchens,etc. Through the model, clients may also focus on other features that are important from model 2 which could return higher ROI with lower cost such as improving garage areas to fit in more cars,etc.
#
# Recommendations will be based on clients' expectations by the minimum price that they would sell, If predicted price is higher than the minimum price, I will suggest the client to sell the house.
